# %%
import pandas as pd
import matplotlib as plt

df = pd.read_excel('covid19.xlsx')
df.head(20)
df[df['Region'] == 'Одесская область']['Infected'].mean()
data_sort = df[df['Region'] == 'Одесская область'].groupby(['Month']).mean()
data_sort.plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='Month'>
